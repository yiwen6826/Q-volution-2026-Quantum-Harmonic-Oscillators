# %%
import numpy as np

from fifth_harmony import *
# Out:
# /home/skellig/miniconda3/envs/GiQ-Hackathon26/lib/python3.12/site-packages/classiq/_internals/authentication/token_manager.py:113: UserWarning: Device is already registered.
# Generating a new refresh token should only be done if the current refresh token is compromised.
# To do so, set the overwrite parameter to true
#   warnings.warn(

# %%
k = 7
omega = 1 # frecuency

y0_vals = [1, 1.5, 2, 2.5, 3] # initial position
vy0_vals = [1, 1.5, 2, 2.5, 3] # initial velocity

# shift to (velocity, equilibrium position)
bx = 0.0
by_vals = np.round(np.arange(0.0, 1.1, 0.1), 1)

# %%
for y0 in y0_vals:
    for vy0 in vy0_vals:
        for by in by_vals:
            print(f"k={k}, omega={omega}, y0={y0}, vy0={vy0}, bx={bx}, by={by}")
            if data_exists(k, omega, y0, vy0, bx, by):
                print("Data exists, skipping computation!\n")
                continue
            else:
                time_range, data_expected, data_actual = harmonic_oscillator(k, omega, y0, vy0, bx, by, msg=False)
                save_data(k, omega, y0, vy0, bx, by, time_range, data_expected, data_actual)
# Out:
# k=7, omega=1, y0=1, vy0=1, bx=0.0, by=0.0
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=1, bx=0.0, by=0.1
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=1, bx=0.0, by=0.2
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=1, bx=0.0, by=0.3
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=1, bx=0.0, by=0.4
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=1, bx=0.0, by=0.5
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=1, bx=0.0, by=0.6
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=1, bx=0.0, by=0.7
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=1, bx=0.0, by=0.8
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=1, bx=0.0, by=0.9
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=1, bx=0.0, by=1.0
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=1.5, bx=0.0, by=0.0
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=1.5, bx=0.0, by=0.1
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=1.5, bx=0.0, by=0.2
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=1.5, bx=0.0, by=0.3
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=1.5, bx=0.0, by=0.4
# All data has been saved at data/k7_w1.0_y1.0_vy1.5_bx0.0_by0.4/
# k=7, omega=1, y0=1, vy0=1.5, bx=0.0, by=0.5
# All data has been saved at data/k7_w1.0_y1.0_vy1.5_bx0.0_by0.5/
# k=7, omega=1, y0=1, vy0=1.5, bx=0.0, by=0.6
# All data has been saved at data/k7_w1.0_y1.0_vy1.5_bx0.0_by0.6/
# k=7, omega=1, y0=1, vy0=1.5, bx=0.0, by=0.7
# All data has been saved at data/k7_w1.0_y1.0_vy1.5_bx0.0_by0.7/
# k=7, omega=1, y0=1, vy0=1.5, bx=0.0, by=0.8
# All data has been saved at data/k7_w1.0_y1.0_vy1.5_bx0.0_by0.8/
# k=7, omega=1, y0=1, vy0=1.5, bx=0.0, by=0.9
# All data has been saved at data/k7_w1.0_y1.0_vy1.5_bx0.0_by0.9/
# k=7, omega=1, y0=1, vy0=1.5, bx=0.0, by=1.0
# All data has been saved at data/k7_w1.0_y1.0_vy1.5_bx0.0_by1.0/
# k=7, omega=1, y0=1, vy0=2, bx=0.0, by=0.0
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=2, bx=0.0, by=0.1
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=2, bx=0.0, by=0.2
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=2, bx=0.0, by=0.3
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=2, bx=0.0, by=0.4
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=2, bx=0.0, by=0.5
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=2, bx=0.0, by=0.6
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=2, bx=0.0, by=0.7
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=2, bx=0.0, by=0.8
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=2, bx=0.0, by=0.9
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=2, bx=0.0, by=1.0
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=2.5, bx=0.0, by=0.0
# All data has been saved at data/k7_w1.0_y1.0_vy2.5_bx0.0_by0.0/
# k=7, omega=1, y0=1, vy0=2.5, bx=0.0, by=0.1
# All data has been saved at data/k7_w1.0_y1.0_vy2.5_bx0.0_by0.1/
# k=7, omega=1, y0=1, vy0=2.5, bx=0.0, by=0.2
# All data has been saved at data/k7_w1.0_y1.0_vy2.5_bx0.0_by0.2/
# k=7, omega=1, y0=1, vy0=2.5, bx=0.0, by=0.3
# All data has been saved at data/k7_w1.0_y1.0_vy2.5_bx0.0_by0.3/
# k=7, omega=1, y0=1, vy0=2.5, bx=0.0, by=0.4
# All data has been saved at data/k7_w1.0_y1.0_vy2.5_bx0.0_by0.4/
# k=7, omega=1, y0=1, vy0=2.5, bx=0.0, by=0.5
# All data has been saved at data/k7_w1.0_y1.0_vy2.5_bx0.0_by0.5/
# k=7, omega=1, y0=1, vy0=2.5, bx=0.0, by=0.6
# All data has been saved at data/k7_w1.0_y1.0_vy2.5_bx0.0_by0.6/
# k=7, omega=1, y0=1, vy0=2.5, bx=0.0, by=0.7
# All data has been saved at data/k7_w1.0_y1.0_vy2.5_bx0.0_by0.7/
# k=7, omega=1, y0=1, vy0=2.5, bx=0.0, by=0.8
# All data has been saved at data/k7_w1.0_y1.0_vy2.5_bx0.0_by0.8/
# k=7, omega=1, y0=1, vy0=2.5, bx=0.0, by=0.9
# All data has been saved at data/k7_w1.0_y1.0_vy2.5_bx0.0_by0.9/
# k=7, omega=1, y0=1, vy0=2.5, bx=0.0, by=1.0
# All data has been saved at data/k7_w1.0_y1.0_vy2.5_bx0.0_by1.0/
# k=7, omega=1, y0=1, vy0=3, bx=0.0, by=0.0
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=3, bx=0.0, by=0.1
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=3, bx=0.0, by=0.2
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=3, bx=0.0, by=0.3
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=3, bx=0.0, by=0.4
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=3, bx=0.0, by=0.5
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=3, bx=0.0, by=0.6
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=3, bx=0.0, by=0.7
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=3, bx=0.0, by=0.8
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=3, bx=0.0, by=0.9
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1, vy0=3, bx=0.0, by=1.0
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1.5, vy0=1, bx=0.0, by=0.0
# All data has been saved at data/k7_w1.0_y1.5_vy1.0_bx0.0_by0.0/
# k=7, omega=1, y0=1.5, vy0=1, bx=0.0, by=0.1
# All data has been saved at data/k7_w1.0_y1.5_vy1.0_bx0.0_by0.1/
# k=7, omega=1, y0=1.5, vy0=1, bx=0.0, by=0.2
# All data has been saved at data/k7_w1.0_y1.5_vy1.0_bx0.0_by0.2/
# k=7, omega=1, y0=1.5, vy0=1, bx=0.0, by=0.3
# All data has been saved at data/k7_w1.0_y1.5_vy1.0_bx0.0_by0.3/
# k=7, omega=1, y0=1.5, vy0=1, bx=0.0, by=0.4
# All data has been saved at data/k7_w1.0_y1.5_vy1.0_bx0.0_by0.4/
# k=7, omega=1, y0=1.5, vy0=1, bx=0.0, by=0.5
# All data has been saved at data/k7_w1.0_y1.5_vy1.0_bx0.0_by0.5/
# k=7, omega=1, y0=1.5, vy0=1, bx=0.0, by=0.6
# All data has been saved at data/k7_w1.0_y1.5_vy1.0_bx0.0_by0.6/
# k=7, omega=1, y0=1.5, vy0=1, bx=0.0, by=0.7
# All data has been saved at data/k7_w1.0_y1.5_vy1.0_bx0.0_by0.7/
# k=7, omega=1, y0=1.5, vy0=1, bx=0.0, by=0.8
# All data has been saved at data/k7_w1.0_y1.5_vy1.0_bx0.0_by0.8/
# k=7, omega=1, y0=1.5, vy0=1, bx=0.0, by=0.9
# All data has been saved at data/k7_w1.0_y1.5_vy1.0_bx0.0_by0.9/
# k=7, omega=1, y0=1.5, vy0=1, bx=0.0, by=1.0
# All data has been saved at data/k7_w1.0_y1.5_vy1.0_bx0.0_by1.0/
# k=7, omega=1, y0=1.5, vy0=1.5, bx=0.0, by=0.0
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1.5, vy0=1.5, bx=0.0, by=0.1
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1.5, vy0=1.5, bx=0.0, by=0.2
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1.5, vy0=1.5, bx=0.0, by=0.3
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1.5, vy0=1.5, bx=0.0, by=0.4
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1.5, vy0=1.5, bx=0.0, by=0.5
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1.5, vy0=1.5, bx=0.0, by=0.6
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1.5, vy0=1.5, bx=0.0, by=0.7
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1.5, vy0=1.5, bx=0.0, by=0.8
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1.5, vy0=1.5, bx=0.0, by=0.9
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1.5, vy0=1.5, bx=0.0, by=1.0
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1.5, vy0=2, bx=0.0, by=0.0
# All data has been saved at data/k7_w1.0_y1.5_vy2.0_bx0.0_by0.0/
# k=7, omega=1, y0=1.5, vy0=2, bx=0.0, by=0.1
# All data has been saved at data/k7_w1.0_y1.5_vy2.0_bx0.0_by0.1/
# k=7, omega=1, y0=1.5, vy0=2, bx=0.0, by=0.2
# All data has been saved at data/k7_w1.0_y1.5_vy2.0_bx0.0_by0.2/
# k=7, omega=1, y0=1.5, vy0=2, bx=0.0, by=0.3
# All data has been saved at data/k7_w1.0_y1.5_vy2.0_bx0.0_by0.3/
# k=7, omega=1, y0=1.5, vy0=2, bx=0.0, by=0.4
# All data has been saved at data/k7_w1.0_y1.5_vy2.0_bx0.0_by0.4/
# k=7, omega=1, y0=1.5, vy0=2, bx=0.0, by=0.5
# All data has been saved at data/k7_w1.0_y1.5_vy2.0_bx0.0_by0.5/
# k=7, omega=1, y0=1.5, vy0=2, bx=0.0, by=0.6
# All data has been saved at data/k7_w1.0_y1.5_vy2.0_bx0.0_by0.6/
# k=7, omega=1, y0=1.5, vy0=2, bx=0.0, by=0.7
# All data has been saved at data/k7_w1.0_y1.5_vy2.0_bx0.0_by0.7/
# k=7, omega=1, y0=1.5, vy0=2, bx=0.0, by=0.8
# All data has been saved at data/k7_w1.0_y1.5_vy2.0_bx0.0_by0.8/
# k=7, omega=1, y0=1.5, vy0=2, bx=0.0, by=0.9
# All data has been saved at data/k7_w1.0_y1.5_vy2.0_bx0.0_by0.9/
# k=7, omega=1, y0=1.5, vy0=2, bx=0.0, by=1.0
# All data has been saved at data/k7_w1.0_y1.5_vy2.0_bx0.0_by1.0/
# k=7, omega=1, y0=1.5, vy0=2.5, bx=0.0, by=0.0
# Data exists, skipping computation!
#
# k=7, omega=1, y0=1.5, vy0=2.5, bx=0.0, by=0.1
